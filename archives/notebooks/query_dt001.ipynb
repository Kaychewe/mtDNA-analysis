# %%
import hail as hl

hl.init(
    default_reference="GRCh38",
    log="/home/jupyter/hail_mtDNA.log"
)

# %%
mt = hl.read_matrix_table(
    "gs://fc-aou-datasets-controlled/v8/wgs/short_read/mt/mt.mt"
)

# %%
mt.count()
